# %%
suallar=[
    {
    'sual':'Cəfər Cabbarlının hansı faciəvi dram əsəri Bakı neft sənayesinin inkişafı fonunda iki sosial təbəqənin (kasib və varlı) mübarizəsindən bəhs edir?',
    'variantlar':['A. Od Gəlini','B. Sevil','C. Almaz', 'D. Solğun Çiçəklər'],
    'cavab':'B'
    },
    {
    'sual':'"Bir Gənc Qızın Xatirələri" romanının müəllifi, həmçinin XX əsrin əvvəllərində Azərbaycan mühacirət ədəbiyyatının görkəmli nümayəndələrindən biri kimdir?',
    'variantlar':['A. Səməd Vurğun', 'B. Cəlil Məmmədquluzadə', 'C. Yusif Vəzir Çəmənzəminli', 'D. Mirzə Ələkbər Sabir'],
    'cavab':'C'
    },

    {
    'sual':'Hüseyn Cavidin yaradıcılığında əsas yeri tutan, mistik, fəlsəfi və romantik üslubu özündə birləşdirən ədəbi cərəyan hansıdır?',
    'variantlar':['A. Tənqidi realizm', 'B. Romantizm', 'C. Simvolizm', 'D. Klassisizm'],
    'cavab':'C'
    },

    {
    'sual':'İsmayıl Şıxlıya böyük şöhrət gətirən və İkinci Dünya müharibəsində döyüşən Azərbaycan əsgərlərinin qəhrəmanlığından bəhs edən məşhur romanı hansıdır?',
    'variantlar':['A. Dəli Kür', 'B. Ayrılan Yollar', 'C. Köç', 'D. Ömürdən Səhifələr'],
    'cavab':'B'
    },

    {
    'sual':'M. F. Axundov dramaturgiya və ədəbi tənqidlə yanaşı, həm də hansı elm sahəsinə böyük maraq göstərmiş və bu sahədə ciddi islahat təklifləri irəli sürmüşdür?',
    'variantlar':['A. Kimya və fizika','B. Riyaziyyat və Həndəsə','C. Astronomiya və kosmoqrafiya','D. Əlifba islahatları və dilçilik'],
    'cavab':'D'
    },

    {
    'sual':'XX əsrin əvvəllərində Azərbaycan maarifçilik hərəkatının rəhbərlərindən biri olan Əli Bəy Hüseynzadənin redaktorluğu ilə nəşr olunan, əsasən "türkləşmək, islamlaşmaq, müasirləşmək" ideologiyasını təbliğ edən ədəbi-fəlsəfi jurnal hansı idi?',
    'variantlar':['A. Molla Nəsrəddin', 'B. Açıq Söz', 'C. Həyat', 'D. Füyuzat'],
    'cavab':'D'
    },
    {
    'sual':'Mirzə Fətəli Axundovun Azərbaycan ədəbiyyatına gətirdiyi janr yeniliyini (realist komediya) davam etdirən və XX əsrin əvvəllərində "Şamdan bəy", "Hacı Qara" kimi komediyalarla tanınan dramaturq kimdir?',
    'variantlar':['A. Cəfər Cabbarlı', 'B. Hüseyn Cavid', 'C. Nəcəf Bəy Vəzirov', 'D. Mirzə Cəlil Məmmədquluzadə'],
    'cavab':'C'
    }


]

def run_quiz(suallar):
  score=0
  for sual in suallar:
    print(sual['sual'])
    for variant in sual['variantlar']:
      print(variant)
    cavabiniz = input('Cavabınızı daxil edin (A,B,C və ya D): ').upper()
    if cavabiniz ==sual['cavab']:
      print('Dogrudur!\n')
      score+=1
    else:
      print('Yanlışdır! Doğru cavab, sual[cavab],\n')
  print(f'Sizin nəticəniz {len(suallar)}-dən {score}-dir')

run_quiz(suallar)
# Out:
# Cəfər Cabbarlının hansı faciəvi dram əsəri Bakı neft sənayesinin inkişafı fonunda iki sosial təbəqənin (kasib və varlı) mübarizəsindən bəhs edir?
# A. Od Gəlini
# B. Sevil
# C. Almaz
# D. Solğun Çiçəklər
# Cavabınızı daxil edin (A,B,C və ya D): d
# Yanlışdır! Doğru cavab, sual[cavab],
#
# "Bir Gənc Qızın Xatirələri" romanının müəllifi, həmçinin XX əsrin əvvəllərində Azərbaycan mühacirət ədəbiyyatının görkəmli nümayəndələrindən biri kimdir?
# A. Səməd Vurğun
# B. Cəlil Məmmədquluzadə
# C. Yusif Vəzir Çəmənzəminli
# D. Mirzə Ələkbər Sabir
# Cavabınızı daxil edin (A,B,C və ya D): d
# Yanlışdır! Doğru cavab, sual[cavab],
#
# Hüseyn Cavidin yaradıcılığında əsas yeri tutan, mistik, fəlsəfi və romantik üslubu özündə birləşdirən ədəbi cərəyan hansıdır?
# A. Tənqidi realizm
# B. Romantizm
# C. Simvolizm
# D. Klassisizm
# Cavabınızı daxil edin (A,B,C və ya D): d
# Yanlışdır! Doğru cavab, sual[cavab],
#
# ...

# %%
run_quiz(suallar)
# Out:
# Cəfər Cabbarlının hansı faciəvi dram əsəri Bakı neft sənayesinin inkişafı fonunda iki sosial təbəqənin (kasib və varlı) mübarizəsindən bəhs edir?
# A. Od Gəlini
# B. Sevil
# C. Almaz
# D. Solğun Çiçəklər
# Cavabınızı daxil edin (A,B,C və ya D): b
# Dogrudur!
#
# "Bir Gənc Qızın Xatirələri" romanının müəllifi, həmçinin XX əsrin əvvəllərində Azərbaycan mühacirət ədəbiyyatının görkəmli nümayəndələrindən biri kimdir?
# A. Səməd Vurğun
# B. Cəlil Məmmədquluzadə
# C. Yusif Vəzir Çəmənzəminli
# D. Mirzə Ələkbər Sabir
# Cavabınızı daxil edin (A,B,C və ya D): c
# Dogrudur!
#
# Hüseyn Cavidin yaradıcılığında əsas yeri tutan, mistik, fəlsəfi və romantik üslubu özündə birləşdirən ədəbi cərəyan hansıdır?
# A. Tənqidi realizm
# B. Romantizm
# C. Simvolizm
# D. Klassisizm
# Cavabınızı daxil edin (A,B,C və ya D): d
# Yanlışdır! Doğru cavab, sual[cavab],
#
# ...
